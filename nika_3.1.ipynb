# %%
import pandas as pd
import numpy as np
data = pd.read_csv('city.csv')

# %%
# %%time
data.shape[0]
# Out:
# Wall time: 0 ns
# 1117

# %%
data.head()
# Out:
#                     address  postal_code country federal_district region_type  \
# 0   Респ Адыгея, г Адыгейск     385200.0  Россия            Южный        Респ
# 1                  г Майкоп     385000.0  Россия            Южный        Респ
# 2           г Горно-Алтайск     649000.0  Россия        Сибирский        Респ
# 3  Алтайский край, г Алейск     658125.0  Россия        Сибирский        край
# 4                 г Барнаул     656000.0  Россия        Сибирский        край
#
#       region area_type area city_type           city  ... fias_level  \
# 0     Адыгея       NaN  NaN         г       Адыгейск  ...          4
# 1     Адыгея       NaN  NaN         г         Майкоп  ...          4
# 2      Алтай       NaN  NaN         г  Горно-Алтайск  ...          4
# 3  Алтайский       NaN  NaN         г         Алейск  ...          4
# 4  Алтайский       NaN  NaN         г        Барнаул  ...          4
#
#   capital_marker        okato        oktmo  tax_office  timezone    geo_lat  \
# ...

# %%
data[['federal_district', 'city', 'population']].head(10)
# Out:
#   federal_district           city population
# 0            Южный       Адыгейск      12689
# 1            Южный         Майкоп     144055
# 2        Сибирский  Горно-Алтайск      62861
# 3        Сибирский         Алейск      28528
# 4        Сибирский        Барнаул     635585
# 5        Сибирский     Белокуриха      15072
# 6        Сибирский          Бийск     203826
# 7        Сибирский         Горняк      13040
# 8        Сибирский        Заринск      47035
# 9        Сибирский    Змеиногорск      10569

# %%
data['federal_district'].value_counts()
# Out:
# Центральный          304
# Приволжский          200
# Северо-Западный      148
# Уральский            115
# Сибирский            114
# Южный                 96
# Дальневосточный       82
# Северо-Кавказский     58
# Name: federal_district, dtype: int64

# %%
py = data[data['federal_district'].isin(['Приволжский', 'Сибирский'])]
py[['timezone','country']].groupby('timezone').count().rename({'country': 'city_count'}, axis=1)
# Out:
#           city_count
# timezone
# UTC+3            101
# UTC+4             41
# UTC+5             58
# UTC+6              6
# UTC+7             86
# UTC+8             22

# %%
data['timezone'].value_counts()
# Out:
# UTC+3     660
# UTC+5     173
# UTC+7      86
# UTC+4      66
# UTC+9      31
# UTC+8      28
# UTC+2      22
# UTC+10     22
# UTC+11     17
# UTC+12      6
# UTC+6       6
# Name: timezone, dtype: int64

# %%
audi = pd.read_csv('audi.csv')

# %%
audi.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %% [markdown]
# Количество моделей

# %%
audi['model'].value_counts()
# Out:
#  A3     1929
#  Q3     1417
#  A4     1381
#  A1     1347
#  A5      882
#  Q5      877
#  Q2      822
#  A6      748
#  Q7      397
#  TT      336
#  A7      122
#  A8      118
#  Q8       69
#  RS6      39
#  RS3      33
#  RS4      31
#  RS5      29
#  R8       28
#  S3       18
#  SQ5      16
#  S4       12
#  SQ7       8
#  S8        4
#  S5        3
#  A2        1
#  RS7       1
# Name: model, dtype: int64

# %% [markdown]
# Сумма продаж каждой модели

# %%
audi[['model', 'price']].groupby('model').sum().sort_values('price', ascending=False)
# Out:
#           price
# model
#  A3    33581039
#  Q3    32589954
#  A4    27972777
#  Q5    26700869
#  A5    20795015
#  A1    19299480
#  Q2    18508954
#  Q7    17780963
#  A6    16976148
#  TT     7319576
#  Q8     4147936
#  A8     4127858
#  A7     3521593
#  R8     2734262
#  RS6    2182591
#  RS4    1554700
#  RS5    1486691
#  RS3    1123667
#  SQ5     502653
#  SQ7     394152
#  S4      374977
#  S3      366830
#  S8      135231
#  S5       47940
#  RS7      33490
#  A2        2490

# %% [markdown]
# Типы топлива

# %%
audi['fuelType'].value_counts()
# Out:
# Diesel    5577
# Petrol    5063
# Hybrid      28
# Name: fuelType, dtype: int64

# %% [markdown]
# 5 самых дешевых машин

# %%
audi[['model', 'year', 'price']].sort_values('price').head(5)
# Out:
#       model  year  price
# 10588    A3  2003   1490
# 10552    A4  2004   1699
# 7795     A3  2005   1975
# 10108    TT  2002   1990
# 7404     A3  2009   2490

# %% [markdown]
# 5 машин с наименьшим расходом

# %%
audi[['model', 'year', 'mpg']].sort_values('mpg').head(5)
# Out:
#       model  year   mpg
# 10427    A8  1997  18.9
# 8941     A6  2004  19.3
# 1869     R8  2013  19.6
# 10171   RS4  2006  20.3
# 9829     S4  2007  20.3
